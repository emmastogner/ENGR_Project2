# %% [markdown]
# <a href="https://colab.research.google.com/github/emmastogner/ENGR_Project2/blob/main/ENGR_Project2_Final_Code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def name():
  name1=input('Hi there, what is your name? ')
  print(f'Thanks, {name1}!')
  return
def major():
  degree=input('What kind of engineering major are you? (mechanical, aerospace, biomedical, chemical, civil, environmental, environmental science, computer science, computer, electrical, industrial and systems, petroleum, or geoscience?)')
  if degree=='mechanical':
    mechanical_clubs()
    return
  elif degree=='aerospace':
    aerospace_clubs()
    return
  elif degree=='biomedical':
    bme_clubs()
    return
  elif degree=='chemical':
    chem_clubs()
    return
  elif degree=='civil':
    civil_clubs()
    return
  elif degree=='environmental':
    environmental_clubs()
    return
  elif degree=='environmental science':
    environmental_clubs()
    return
  elif degree=='computer science':
    cs_clubs()
    return
  elif degree=='computer':
    comp_clubs()
    return
  elif degree=='electrical':
    electric_clubs()
    return
  elif degree=='industrial and systems':
    ise_clubs()
    return
  elif degree=='petroleum':
    pet_clubs()
    return
  elif degree=='geoscience':
    geo_clubs()
    return
  else:
    major()
    return
def mechanical_clubs():
  print('You should consider joining the American Society of Mechanical Engineers (ASME), and if you are interested in a competition team, Sooner Off-Road (SOR)')
  ASME=input('If you are interested in getting more information about ASME answer "Y": ')
  if ASME=='Y':
    print('The American Society of Mechanical Engineers chapter at OU is part of a national organization who\'s goal is the connect and enrich OU mechanical engineering students.')
    print('For more information follow Instagram @ou_asme , Twitter @OU_ASME, and Facebook @University of Oklahoma ASME')
  else:
    print('Okay, let\'s move on.')
  SOR=input('If you are interested in getting more information about SOR answer "Y": .')
  if SOR=='Y':
    print('Sooner Off-Road is a competition team that creates and races off-road vehicles annually and competes against other teams around the nation and globe.')
    print('For more information follow Instagram @sooneroffroad , Twitter @SoonerOffRoad, and check out the ENGAGE page https://ou.campuslabs.com/engage/organization/sooner-off-road .')
  else:
    ('Okay, let\'s move on.')
  return
def aerospace_clubs():
  print('You should consider joining the American Institute of Aeronautics and Astronautics (AIAA) and if you are interested in a competition team, OU Design/Build/Fly (DBF).')
  AIAA=input('If you are interested in getting more information about AIAA answer "Y": .')
  if AIAA=='Y':
    print('')
  else:
    print('Okay, let\'s move on.')
  DBF=input('If you are interested in getting more information about DBF answer "Y": .')
  if DBF=="Y":
    print('')
  else:
    print('Okay, let\'s move on.')
  return
def bme_clubs():
  status=input('Are you an undergraduate or a graduate student? Enter "U" for undergrad or "G" for grad: ')
  if status=='U':
    print('You should consider joining Biomedical Engineering Society (BMSE).')
    BMSE=input('If you are interested in getting more information on BMSE answer "Y": .')
    if BMSE=='Y':
      print('')
    else:
      print('Okay, let\'s move on.')
  elif status=='G':
    print('You should consider joining Biomedical Engineering Student Affairs (BESA).')
    BESA=input('If you are interested in hearing more information about BESA answer "Y": .')
    if BESA=='Y':
      print('')
    else:
      print('Okay, let\'s move on.')
  else:
    return bme_clubs()
  return
def chem_clubs():
  print('You should consider joining American Institute of Chemical Engineers (AIChE) or Society of Plastic Engineers.')
  AIChE=input('If you are interested in getting more information about AIChE, answer "Y", if not then answer "N": ')
  if AIChE=='Y':
    print('')
  else:
    print('Okay, let\'s move on.')
  plastic=input('If you are interested in getting more information on the Society of Plastic Engineers answer "Y", if not then answer "N": ')
  if plastic=='Y':
    print('')
  else:
    print('Okay, let\'s move on.')
  return
def civil_clubs():
  print('You should consider joining American Society of Civil Engineers (ASCE).')
  ASCE=input('If you are interested in getting more information about ASCE answer "Y", if not then answer "N": ')
  if ASCE=='Y':
    print('')
  else:
     print('Okay, let\'s move on.')
  return
def environmental_clubs():
  print('You should consider joining the Environmental Science Student Association (ESSA).')
  ESSA=input('If you are interested in getting more information about ESSA answer "Y", if not then answer "N": ')
  if ESSA=="Y":
    print('')
  else:
    print('Okay, let\'s move on.')
  return
def cs_clubs():
  gender=input('Do you identify as a woman? Answer "Y" or "N": ')
  if gender=='Y':
    print('You should consider joining Association for Women in Computing (AWC)')
    AWC=input('If you are interested in getting more information about AWC answer "Y", if not then answer "N": ')
    if AWC=='Y':
      print('')
    else:
      print('Okay, let\'s move on.')
  else:
    print('')
  print('You should consider joining Computer Science Student Board (CSSB) or Game Developer Association (GDA)')
  CSSB=input('If you are interested in getting more information about GSSB answer "Y", if not then answer "N": ')
  if CSSB=='Y':
    print('')
  else:
    print('Okay, let\'s move on.')
  GDA=input('If you are interested in getting more information about GDA answer "Y", if not then answer "N": ')
  if GDA=='Y':
    print('')
  else:
    print('Okay, let\'s move on.')
  return
def comp_clubs():
  year=input('Are you a Junior or a Senior? Answer "Y" or "N": ')
  if year=='Y':
    print('You should consider joining Eta Kappa Nu')
    EKN=input('If you are interested in getting more information about Eta Kappa Nu answer "Y", if not answer "N": ')
    if EKN=="Y":
      print('')
    else:
      print('Okay, let\'s move on.')
  else:
    cs=input('Sorry, but there are no computer engineering specific clubs. Would you like to hear about the computer science clubs? "Y" or "N": ')
    if cs=='Y':
      return cs_clubs
    else:
      print('Okay, let\'s move on.')
  return
def electric_clubs():
  year=input('Are you a Junior or a Senior? Answer "Y" or "N": ')
  if year=='Y':
    print('You should consider joining Eta Kappa Nu')
    EKN=input('If you are interested in getting more information about Eta Kappa Nu answer "Y", if not answer "N": ')
    if EKN=="Y":
      print('')
    else:
      print('Okay, let\'s move on.')
  else:
    print('')
  print('You should consider joining Institute of Electrical and Electronics Engineers (IEEE).')
  IEEE=input('If you are interested in getting more information about IEEE answer "Y", if not answer "N": ')
  if IEEE=='Y':
    print('')
  else:
    print('Okay, let\'s move on.')
  return
def ise_clubs():
  status=input('Are you an PhD student? "Y" or "N": ')
  if status=='Y':
    print('You should consider joining Institute for Operations Research and Management Sciences (INFORM)')
    INFORM=input('If you are interested in getting more information about INFORM answer "Y", if not answer "N": ')
    if INFORM=='Y':
      print('')
    else:
       print('Okay, let\'s move on.')
  return
def pet_clubs():
  print('''You should consider joining American Association of Drilling Engineers (AADE), American Association of Petroleum Geologists (AAPG),
   Pi Epsilon Tai (PiET), Society of Petroleum Engineers, or Society of Petrophysicists and Well Log Analysts (SPWLA)''')
  AADE=input('/nIf you are interested in getting more information about AADE answer "Y", if not answer "N": ')
  if AADE=='Y':
    print('')
  else:
    print('Okay, let\'s move on.')
  AAPG=input('/nIf you are interested in getting more information about AAPG answer "Y", if not answer "N": ')
  if AAPG=='Y':
    print('')
  else:
     print('Okay, let\'s move on.')
  PiET=input('/nIf you are interested in getting more information about PiET answer "Y", if not answer "N": ')
  if PiET=='Y':
    print('')
  else:
     print('Okay, let\'s move on.')
  SPWLA=input('/nIf you are interested in getting more information about SPWLA answer "Y", if not answer "N": ')
  if SPWLA=='Y':
    print('')
  else:
     print('Okay, let\'s move on.')
  return
def geo_clubs():
  print('You should consider joining Pick and Hammer or Society of Exploration Geophysicists (SEG)')
  pick=input('\nIf you are interested in getting more information about Pick and Hammer answer "Y", if not then answer "N": ')
  if pick=='Y':
    print('')
  else:
    print('Okay, let\'s move on.')
  SEG=input('\nIf you are interested in getting more information about SEG answer "Y", if not then answer "N": ')
  if SEG=='Y':
    print('')
  else:
    print('Okay, let\'s move on.')
  return
def competition():
  print('Are you interested in joining a competition team?')
  comp=input('Answer "Y" or "N": ')
  if comp=='Y':
    print('''You should consider joining OU Boomer Rocket Team (BRT), Concrete Canoe, OU Design/Build/Fly (DBF), Sooner Competitive Robotics (SCR),
    Sooner Off-Road (SOR), Sooner Racing Team, Sooner Rover Team, Steel Bridge, or Students for the Exploration and Development of Space (SEDS)''')
    BRT=input('\nIf you are interested in getting more information about BRT answer "Y", if not then answer "N": ')
    if BRT=='Y':
      print('')
    else:
      print('Okay, let\'s move on.')
    DBF=input('\nIf you are interested in getting more information about DBF answer "Y", if not then answer "N": ')
    if DBF=='Y':
      print('')
    else:
      print('Okay, let\'s move on.')
    SCR=input('\nIf you are interested in getting more information about SCR answer "Y", if not then answer "N": ')
    if SCR=='Y':
      print('')
    else:
        print('Okay, let\'s move on.')
    SOR=input('\nIf you are interested in getting more information about SOR answer "Y", if not then answer "N": ')
    if SOR=='Y':
      print('')
    else:
       print('Okay, let\'s move on.')
    Racing=input('\nIf you are interested in getting more information about Sooner Racing Team answer "Y", if not then answer "N": ')
    if Racing=='Y':
      print('')
    else:
       print('Okay, let\'s move on.')
    Rover=input('\nIf you are interested in getting more information about Sooner Rover Team answer "Y", if not then answer "N": ')
    if Rover=='Y':
      print('')
    else:
      print('Okay, let\'s move on.')
    Bridge=input('\nIf you are interested in getting more information about Steel Bridge answer "Y", if not then answer "N": ')
    if Bridge=='Y':
      print('')
    else:
       print('Okay, let\'s move on.')
    SEEDS=input('\nIf you are interested in getting more information about SEEDS answer "Y", if not then answer "N": ')
    if SEEDS=='Y':
      print('')
    else:
      print('Okay, let\'s move on.')
    return
def general():
  gender=input('What gender do you identify as? Answer "male", "female", or "other": ')
  if gender=='female':
    print('\nYou should consider joining Alpha Sigma Kappa (ASK) - Women in Technical Studies or Society of Women Engineers (SWE).')
    ASK=input('\nIf you are interested in getting more information about ASK answer "Y", if not then answer "N": ')
    if ASK=='Y':
      print('')
    else:
      print('Okay, let\'s move on.')
    SWE=input('\nIf you are interested in getting more information about SWE answer "Y", if not then answer "N": ')
    if SWE=='Y':
      print('')
    else:
      print('Okay, let\'s move on.')
  elif gender=='male':
    print('\nYou should consider joining Triangle Fraternity')
    Triangle=input('\nIf you are interested in getting more information about Triangle Fraternity answer "Y", if not then answer "N": ')
    if Triangle=='Y':
      print('')
    else:
      print('Okay, let\'s move on.')
  else:
    print()
  ethnicity=input('What is your ethnicity? Answer "Black", "Asian", "Hispanic", "Indigenous", or "White"')
  if ethnicity=='Black':
    print('\nYou should consider joining National Society of Black Engineers (NSBE)')
    NSBE=input('\nIf you are interested in getting more information about NSBE answer "Y", if not then answer "N": ')
    if NSBE=='Y':
      print()
    else:
      print('Okay, let\'s move on.')
  elif ethnicity=='Asian':
    print('\nYou should consider joining Society of Asian Scientists and Engineers (SASE)')
    SASE=input('\nIf you are interested in getting more information about SASE answer "Y", if not then answer "N": ')
    if SASE=='Y':
      print()
    else:
      print('Okay, let\'s move on.')
  elif ethnicity=='Hispanic':
    print('\nYou should consider joining Society of Hispanic Professional Engineers (SHPE)')
    SHPE=input('\nIf you are interested in getting more information about SHPE answer "Y", if not then answer "N": ')
    if SHPE=='Y':
      print()
    else:
      print('Okay, let\'s move on.')
  elif ethnicity=='Indigenous':
    print('\nYou should consider joining Society of American Indian Science and Engineering Society (AISES)')
    AISES=input('\nIf you are interested in getting more information about AISES answer "Y", if not then answer "N": ')
    if AISES=='Y':
      print()
    else:
      print('Okay, let\'s move on.')
  else:
    print()
  LGBTQ=input('\nAre part of the LQBTQ+ community? Answer "Y" or "N": ')
  if LGBTQ=='Y':
    print('\nYou should consider joining oSTEM.')
    oSTEM=input('If you are interested in getting more information about oSTEM answer "Y", if not then answer "N": ')
    if oSTEM=='Y':
      print()
    else:
      print('Okay, let\'s move on.')
  else:
    print()
  print('\nSome other general engineering clubs at OU are Engineer\'s Club, Engineers Serving Others (ESO), Hacklahoma, and Tau Beta Pi ')
  Eclub=input('If you are interested in getting more information about Engineer\'s Club answer "Y", if not then answer "N": ')
  if Eclub=='Y':
    print()
  else:
    print()
  ESO=input('If you are interested in getting more information about ESO answer "Y", if not then answer "N": ')
  if ESO=='Y':
    print()
  else:
    print()
  Hack=input('If you are interested in getting more information about Hacklahoma answer "Y", if not then answer "N": ')
  if Hack=='Y':
    print()
  else:
    print()
  Tau=input('If you are interested in getting more information about Tau Beta Pi answer "Y", if not then answer "N": ')
  if Tau=='Y':
    print()
  else:
    print()
  return


name()
major()
competition()
general()
# Out:
# Hi there, what is your name? emma
# Thanks, emma!
# What kind of engineering major are you? (mechanical, aerospace, biomedical, chemical, civil, environmental, environmental science, computer science, computer, electrical, industrial and systems, petroleum, or geoscience?)mechanical
# You should consider joining the American Society of Mechanical Engineers (ASME), and if you are interested in a competition team, Sooner Off-Road (SOR)
# If you are interested in getting more information about ASME answer "Y": Y
# The American Society of Mechanical Engineers chapter at OU is part of a national organization who's goal is the connect and enrich OU mechanical engineering students.
# For more information follow Instagram @ou_asme , Twitter @OU_ASME, and Facebook @University of Oklahoma ASME
# If you are interested in getting more information about SOR answer "Y": .Y
# ...
